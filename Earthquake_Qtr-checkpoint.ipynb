# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import geopandas as gpd
from datetime import datetime

# %%
#Import data
df = pd.read_csv(os.path.join("1Qtr_EQ.csv"), parse_dates=['time'], usecols = ['time', 'latitude', 'longitude', 'depth', 'mag', 'place'])
df
# Out:
#                                  time   latitude   longitude   depth   mag  \
# 0    2022-03-31 23:47:44.170000+00:00  17.943333  -66.996500    5.77  2.50
# 1    2022-03-31 23:32:34.458000+00:00 -22.807000  171.084500   10.00  4.60
# 2    2022-03-31 23:18:16.617000+00:00  -4.807800  139.426700   10.00  5.20
# 3    2022-03-31 23:13:42.735000+00:00 -22.881900  170.807100   10.00  4.40
# 4    2022-03-31 23:13:07.561000+00:00  41.419300   72.909700   10.00  4.20
# ...                               ...        ...         ...     ...   ...
# 7015 2022-01-01 02:17:56.815000+00:00  38.725100   73.482700  105.79  4.20
# 7016 2022-01-01 01:38:57.636000+00:00  52.922000 -163.660500   10.00  3.10
# 7017 2022-01-01 00:27:51.990000+00:00  40.477167 -124.322333   19.08  2.88
# 7018 2022-01-01 00:10:28.735000+00:00  -8.763300  124.351300  104.90  4.10
# 7019 2022-01-01 00:02:24.512000+00:00 -17.026900 -174.214200   60.87  4.60
#
#                                       place
# 0      6 km ESE of La Parguera, Puerto Rico
# 1          southeast of the Loyalty Islands
# 2     252 km NW of Kiunga, Papua New Guinea
# 3          southeast of the Loyalty Islands
# 4     44 km NNE of Bazar-Korgon, Kyrgyzstan
# ...                                     ...
# 7015        74 km NW of Murghob, Tajikistan
# 7016            194 km SE of Akutan, Alaska
# 7017               12km SSW of Ferndale, CA
# 7018  48 km N of Pante Makasar, Timor Leste
# 7019            126 km SSW of Hihifo, Tonga
#
# [7020 rows x 6 columns]

# %%
#To check data types
df.dtypes
# Out:
# time         datetime64[ns, UTC]
# latitude                 float64
# longitude                float64
# depth                    float64
# mag                      float64
# place                     object
# dtype: object

# %%
#To check data file type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#To copy datafile to work with
df2 = df.copy()
print(df2)
# Out:
#                                  time   latitude   longitude   depth   mag  \
# 0    2022-03-31 23:47:44.170000+00:00  17.943333  -66.996500    5.77  2.50
# 1    2022-03-31 23:32:34.458000+00:00 -22.807000  171.084500   10.00  4.60
# 2    2022-03-31 23:18:16.617000+00:00  -4.807800  139.426700   10.00  5.20
# 3    2022-03-31 23:13:42.735000+00:00 -22.881900  170.807100   10.00  4.40
# 4    2022-03-31 23:13:07.561000+00:00  41.419300   72.909700   10.00  4.20
# ...                               ...        ...         ...     ...   ...
# 7015 2022-01-01 02:17:56.815000+00:00  38.725100   73.482700  105.79  4.20
# 7016 2022-01-01 01:38:57.636000+00:00  52.922000 -163.660500   10.00  3.10
# 7017 2022-01-01 00:27:51.990000+00:00  40.477167 -124.322333   19.08  2.88
# 7018 2022-01-01 00:10:28.735000+00:00  -8.763300  124.351300  104.90  4.10
# 7019 2022-01-01 00:02:24.512000+00:00 -17.026900 -174.214200   60.87  4.60
#
#                                       place
# 0      6 km ESE of La Parguera, Puerto Rico
# 1          southeast of the Loyalty Islands
# 2     252 km NW of Kiunga, Papua New Guinea
# 3          southeast of the Loyalty Islands
# 4     44 km NNE of Bazar-Korgon, Kyrgyzstan
# ...                                     ...
# 7015        74 km NW of Murghob, Tajikistan
# 7016            194 km SE of Akutan, Alaska
# 7017               12km SSW of Ferndale, CA
# 7018  48 km N of Pante Makasar, Timor Leste
# 7019            126 km SSW of Hihifo, Tonga
#
# [7020 rows x 6 columns]

# %%
#To check copied file
df2.dtypes
# Out:
# time         datetime64[ns, UTC]
# latitude                 float64
# longitude                float64
# depth                    float64
# mag                      float64
# place                     object
# dtype: object

# %%
#To check copied file
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
#To seperate date and time
df2['date'] = [d.date() for d in df2['time']]
df2['time'] = [d.time() for d in df2['time']]
df2
# Out:
#                  time   latitude   longitude   depth   mag  \
# 0     23:47:44.170000  17.943333  -66.996500    5.77  2.50
# 1     23:32:34.458000 -22.807000  171.084500   10.00  4.60
# 2     23:18:16.617000  -4.807800  139.426700   10.00  5.20
# 3     23:13:42.735000 -22.881900  170.807100   10.00  4.40
# 4     23:13:07.561000  41.419300   72.909700   10.00  4.20
# ...               ...        ...         ...     ...   ...
# 7015  02:17:56.815000  38.725100   73.482700  105.79  4.20
# 7016  01:38:57.636000  52.922000 -163.660500   10.00  3.10
# 7017  00:27:51.990000  40.477167 -124.322333   19.08  2.88
# 7018  00:10:28.735000  -8.763300  124.351300  104.90  4.10
# 7019  00:02:24.512000 -17.026900 -174.214200   60.87  4.60
#
#                                       place        date
# 0      6 km ESE of La Parguera, Puerto Rico  2022-03-31
# 1          southeast of the Loyalty Islands  2022-03-31
# 2     252 km NW of Kiunga, Papua New Guinea  2022-03-31
# 3          southeast of the Loyalty Islands  2022-03-31
# 4     44 km NNE of Bazar-Korgon, Kyrgyzstan  2022-03-31
# ...                                     ...         ...
# 7015        74 km NW of Murghob, Tajikistan  2022-01-01
# 7016            194 km SE of Akutan, Alaska  2022-01-01
# 7017               12km SSW of Ferndale, CA  2022-01-01
# 7018  48 km N of Pante Makasar, Timor Leste  2022-01-01
# 7019            126 km SSW of Hihifo, Tonga  2022-01-01
#
# [7020 rows x 7 columns]

# %%
#worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))   Longitude  YlOrBr

# %%
#To plot using geopandas on a worldmap
#Note:  Geopandas is not an easy application to install if you don't use it.  It is really cool for this map.
worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
fig, ax = plt.subplots(figsize=(18, 9))
worldmap.plot(color="lightgrey", ax=ax)
x = df2['longitude']
y = df2['latitude']
z = df2['mag']
plt.scatter(x, y, s=10*z, c=z, alpha=0.6, vmin=0, cmap='autumn_r')
plt.colorbar(label='Magnitude')
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.title("Earthquakes for 1st Quarter 2022")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
df2
# Out:
#                  time   latitude   longitude   depth   mag  \
# 0     23:47:44.170000  17.943333  -66.996500    5.77  2.50
# 1     23:32:34.458000 -22.807000  171.084500   10.00  4.60
# 2     23:18:16.617000  -4.807800  139.426700   10.00  5.20
# 3     23:13:42.735000 -22.881900  170.807100   10.00  4.40
# 4     23:13:07.561000  41.419300   72.909700   10.00  4.20
# ...               ...        ...         ...     ...   ...
# 7015  02:17:56.815000  38.725100   73.482700  105.79  4.20
# 7016  01:38:57.636000  52.922000 -163.660500   10.00  3.10
# 7017  00:27:51.990000  40.477167 -124.322333   19.08  2.88
# 7018  00:10:28.735000  -8.763300  124.351300  104.90  4.10
# 7019  00:02:24.512000 -17.026900 -174.214200   60.87  4.60
#
#                                       place        date
# 0      6 km ESE of La Parguera, Puerto Rico  2022-03-31
# 1          southeast of the Loyalty Islands  2022-03-31
# 2     252 km NW of Kiunga, Papua New Guinea  2022-03-31
# 3          southeast of the Loyalty Islands  2022-03-31
# 4     44 km NNE of Bazar-Korgon, Kyrgyzstan  2022-03-31
# ...                                     ...         ...
# 7015        74 km NW of Murghob, Tajikistan  2022-01-01
# 7016            194 km SE of Akutan, Alaska  2022-01-01
# 7017               12km SSW of Ferndale, CA  2022-01-01
# 7018  48 km N of Pante Makasar, Timor Leste  2022-01-01
# 7019            126 km SSW of Hihifo, Tonga  2022-01-01
#
# [7020 rows x 7 columns]
